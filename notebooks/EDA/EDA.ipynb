# %% [markdown]
# # Hate Speech Detection - Exploratory Data Analysis (EDA)
#
# **Student Name:** [Your Name]
# **Student ID:** [Your Student ID]
# **Course:** 5CCSACCA Cloud Computing for Artificial Intelligence
# **Date:** [Current Date]

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Set plot style
sns.set(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## 1. Load the Raw Data
#
# First, we'll load the Davidson Hate Speech dataset into a Pandas DataFrame.

# %%
# Replace 'path_to_file.csv' with the actual path to your Davidson dataset
df = pd.read_csv('data/raw_data/labeled_data.csv')

# Display the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Replace 'path_to_file.csv' with the actual path to your Davidson dataset
# ----> 2 df = pd.read_csv('data/raw_data/labeled_data.csv')
#       4 # Display the first few rows
#       5 df.head()
#
# ...

# %% [markdown]
# ## 2. Understand the Data Structure
#
# Let's get an overview of the dataset, including data types and missing values.

# %%
# Basic information about the dataset
print("Dataset Information:")
print(df.info())

# Statistical summary
print("\nStatistical Summary:")
print(df.describe())

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Information:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Basic information about the dataset
#       2 print("Dataset Information:")
# ----> 3 print(df.info())
#       5 # Statistical summary
#       6 print("\nStatistical Summary:")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Analyze Class Distribution
#
# Visualize the distribution of labels to identify any class imbalances.

# %%
# Replace 'label_column' with the actual name of your label column, e.g., 'class'
label_column = 'label'  # Example label column name

plt.figure(figsize=(8,6))
sns.countplot(x=label_column, data=df)
plt.title('Class Distribution')
plt.xlabel('Classes')
plt.ylabel('Count')
plt.show()

# Display class counts
print("Class Counts:")
print(df[label_column].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Replace 'label_column' with the actual name of your label column, e.g., 'class'
#       2 label_column = 'label'  # Example label column name
# ----> 4 plt.figure(figsize=(8,6))
#       5 sns.countplot(x=label_column, data=df)
#       6 plt.title('Class Distribution')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## 4. Text Data Insights
#
# ### 4.1 Text Length Analysis
#
# Understanding the distribution of text lengths helps in deciding preprocessing steps like truncation.

# %%
# Calculate text lengths
df['text_length'] = df['text'].apply(lambda x: len(str(x).split()))

# Plot distribution of text lengths
plt.figure(figsize=(10,6))
sns.histplot(df['text_length'], bins=50, kde=True)
plt.title('Distribution of Text Lengths')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# Display basic statistics of text lengths
print("Text Length Statistics:")
print(df['text_length'].describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Calculate text lengths
# ----> 2 df['text_length'] = df['text'].apply(lambda x: len(str(x).split()))
#       4 # Plot distribution of text lengths
#       5 plt.figure(figsize=(10,6))
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 4.2 Word Cloud Visualization
#
# Generate word clouds for each class to visualize the most frequent words.

# %%
# Function to generate and display word cloud
def generate_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(15, 7.5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=20)
    plt.axis('off')
    plt.show()

# Generate word clouds for each class
classes = df[label_column].unique()

for cls in classes:
    class_text = ' '.join(df[df[label_column] == cls]['text'].astype(str))
    generate_wordcloud(class_text, f'Word Cloud for Class: {cls}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       8     plt.show()
#      10 # Generate word clouds for each class
# ---> 11 classes = df[label_column].unique()
#      13 for cls in classes:
#      14     class_text = ' '.join(df[df[label_column] == cls]['text'].astype(str))
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 4.3 Common Words and N-grams
#
# Identify common words and bi-grams associated with each class.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Function to display top n words
def top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# Display top 10 words for each class
for cls in classes:
    print(f"\nTop 10 words for class '{cls}':")
    top_words = top_n_words(df[df[label_column] == cls]['text'], 10)
    for word, freq in top_words:
        print(f"{word}: {freq}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      10     return words_freq[:n]
#      12 # Display top 10 words for each class
# ---> 13 for cls in classes:
#      14     print(f"\nTop 10 words for class '{cls}':")
#      15     top_words = top_n_words(df[df[label_column] == cls]['text'], 10)
#
# NameError: name 'classes' is not defined

# %% [markdown]
# ## 5. Identify Potential Issues
#
# ### 5.1 Detect Duplicates
#
# Check for duplicate entries that may bias the model.

# %%
# Check for duplicate rows
duplicate_count = df.duplicated().sum()
print(f"Total Duplicate Rows: {duplicate_count}")

# Optionally, remove duplicates
# df = df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Check for duplicate rows
# ----> 2 duplicate_count = df.duplicated().sum()
#       3 print(f"Total Duplicate Rows: {duplicate_count}")
#       5 # Optionally, remove duplicates
#       6 # df = df.drop_duplicates()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 6. Summary of EDA Findings
#
# - **Class Distribution:** [Summarize any imbalances]
# - **Text Length:** [Summarize insights from text length analysis]
# - **Common Words:** [Highlight any notable words or patterns]
# - **Duplicates:** [Mention if duplicates were found and handled]
# - **Missing Values:** [State if any missing values were present and handled]

# %% [markdown]
# # End of EDA
#
# Proceed to **Data Cleaning** based on the insights gathered from EDA.
